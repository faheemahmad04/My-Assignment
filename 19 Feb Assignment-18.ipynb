# %% [markdown]
# 19 Feb Assignment-18
#
# Both Questions and Answers are written:---

# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Ans:- It is a web framework that allows developers to build lightweight web applications quickly and easily with flask libraries.
#
# Advantages:---
#
# It  is a lightweight backend framework with minimal dependencies.
#
# It is a flexible framework because it allows us to customize and extend the framework to suit our need easily.
#
# It can be used with any database like:- SQL and NoSQL, and with any frontend technology such as React or Angular.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# Ans:-
#
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route('/')
#
# def msg():
#
#     return 'Hello World!!'
#
# if __name__ == '__main__':
#
#     app.run()

# %% [markdown]
# ![Screenshot (12).png](attachment:764cb394-6092-4932-bc26-986a98e4075c.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# Ans:- App Routing means mapping the URLs to a specific function that will handle the logic for that URL. App Routing used to provides the user to remember the URL. It is useful to access the web page directly without navigating from home page.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
#
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999
#
# Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# Ans:-
#
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/welcome")
#
# def welcome_msg():
#
#     return “Welcome to ABC Corporation”
#
# @app.route("/")
#
# def details():
#
#     return "Company Name: ABC Corporation\n Location: India\nContact Detail: 999-999-9999"
#
# if __name__ == "__main__":
#
#     app.run(debug = True)

# %% [markdown]
# ![Screenshot (13).png](attachment:6ead1bc2-eff8-4a58-bb8c-1efcc4fc064d.png)

# %% [markdown]
# ![Screenshot (15).png](attachment:7179f781-3ca0-44e3-b118-58d1e8ebe7f5.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# Ans:- url_for() function. This function accepts the name of the function as the first argument, and the function named user(name) accepts the value through the input URL. It checks whether the received argument matches the ‘admin’ argument or not. If it matches, then the function hello_admin() is called else the hello_guest() is called.
#
# Demo:---
#
# from flask import Flask, redirect, url_for
#
# app = Flask(__name__)
#
# @app.route('/admin')
#
# def hello_admin():
#
# 	return 'Hello Admin'
#
# @app.route('/guest/<guest>')
#
# def hello_guest(guest):
#
#     return 'Hello %s as Guest' % guest
#
# @app.route('/user/<name>')
#
# def hello_user(name):
#
#    if name == 'admin':
#
# 		return redirect(url_for('hello_admin'))
#
# 	else:
#
# 		return redirect(url_for('hello_guest', guest=name))
#
# if __name__ == '__main__':
#
# 	app.run(debug=True)
